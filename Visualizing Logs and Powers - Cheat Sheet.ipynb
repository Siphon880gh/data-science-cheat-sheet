# %% [markdown]
# # Visualizing Logs and Powers - Cheat Sheet
#
# ## By Weng Fei Fung
#
# I also explore some basic logarithmic and power plotting with matplotlib. These explorations form a cheat sheet and example list.

# %%
import pylab
import matplotlib.pyplot as plt
import math

# Exponential function y = 10^x
data = [10**i for i in range(5)]

plt.plot(data)
